# %%
from selfoptforest import *

import sklearn.datasets
X, y = sklearn.datasets.load_iris(return_X_y = True)

# %%
# %matplotlib notebook
sorf = SelfOptRF()
sorf.fit(X, y, max_forest_size = 100, visualize = True)
#sorf.predict(X)
# Out:
# <img src="data:image/png;base64,..." width="678">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-429b7ee89352> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'notebook')
#       2 sorf = SelfOptRF()
# ----> 3 sorf.fit(X, y, max_forest_size = 100, visualize = True)
#       4 #sorf.predict(X)
#
# ~/Dropbox/Uni/Sabana/papers/pcaforests/publications/automl2022/paper/selfoptforest.py in fit(self, X, y, visualize, max_forest_size, seed)
#     295             rf.setup(X, y)
#     296
# --> 297         self.compute_optimal_forest(self.train_new_tree_and_return_new_oob_accuracy, ["standard", "lda", "pca"], max_forest_size = max_forest_size, visualize  = visualize)
#     298         self.prediction_model = self.rfs[self.choice]
#     299
#
# ...
